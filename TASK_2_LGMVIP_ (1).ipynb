# %% [markdown]
# # **Lets Grow More (LGMVIP-2021 September)**
# ## **Task 2 (Intermediate Level)**: Prediction using Decision Tree Algorithm
# ### **Author**: SOUL MARIYA JAMES

# %% [markdown]
# **IMPORTING THE REQUIRED LIBRARIES**

# %%
import pandas as pd
import numpy as np
import sklearn.datasets as datasets
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **LOADING THE DATASET**

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# **DATA EXPLORATION**

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
y=iris.target

# %% [markdown]
# **CHECKING FOR NULL VALUES**

# %%
iris_df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %% [markdown]
# There is no null values present in the dataset.

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.057333           3.758000          1.199333
# std             0.828066          0.435866           1.765298          0.762238
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %%
iris_df.shape
# Out:
# (150, 4)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
iris_df.plot()

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
iris_df.corr()
# Out:
#                    sepal length (cm)  ...  petal width (cm)
# sepal length (cm)           1.000000  ...          0.817941
# sepal width (cm)           -0.117570  ...         -0.366126
# petal length (cm)           0.871754  ...          0.962865
# petal width (cm)            0.817941  ...          1.000000
#
# [4 rows x 4 columns]

# %%
sns.heatmap(iris_df.corr(),annot=True)

# %% [markdown]
# **SPLITTING INTO TRAINING DATA AND TESTING DATA**

# %%
X=iris.data[:,:]
Y=iris.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,random_state=1,test_size=0.1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=1) 
tree = DecisionTreeClassifier()
tree.fit(X_train,Y_train)
print("Training is done successfully.")
# Out:
# Training is done successfully.

# %% [markdown]
# **PREDICTION ON TEST DATA**

# %%
Y_pred = tree.predict(X_test)
print(Y_pred)
# Out:
# [0 1 1 0 2 1 2 0 0 2 1 0 2 1 1]

# %% [markdown]
# **ACCURACY OF THE MODEL**

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print("The Accuracy of our Model is: {}".format(accuracy_score(Y_test,Y_pred)))
# Out:
# The Accuracy of our Model is: 1.0

# %% [markdown]
# The Decision Tree Model has a 100% accuracy.Therefore this model is good.

# %% [markdown]
# **PREDICTION USING NEW DATA**

# %%
new_data =[[3.3, 4.0, 4.1, 2.3]]
Y_pred =tree.predict(new_data)
print(Y_pred)
# Out:
# [1]

# %% [markdown]
# **MODEL VISUALIZATION**

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)
plt.figure(figsize  = (18,18))
tree.plot_tree(clf,filled = True,rounded = True,proportion = True,node_ids = True)
plt.show()

# %% [markdown]
# ## **CONCLUSION**

# %% [markdown]
# We have predicted using Decision Tree Classifier and also visualized graphically.

# %% [markdown]
# ## **THANKYOU!!!**
